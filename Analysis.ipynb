# %%
import pandas as pd

# %%
data = pd.read_csv('items_carsales_4.csv')

# %%
data.head()
# Out:
#             _type drive_type  engine_capacity fuel_type  \
# 0  DealFinderItem        2WD              1.6    Petrol
# 1  DealFinderItem        4WD              2.0    Diesel
# 2  DealFinderItem        NaN              2.0    Petrol
# 3  DealFinderItem        NaN              1.8    Petrol
# 4  DealFinderItem        NaN              2.0    Petrol
#
#                                      id    make  manufacturer_marketing_year  \
# 0        Chery-J11-2014/OAG-AD-15997339   Chery                          NaN
# 1  Great-Wall-X200-2013/OAG-AD-16010569   Great                          NaN
# 2                                   NaN    Jeep                          NaN
# 3                                   NaN  Holden                          NaN
# 4                                   NaN    Jeep                          NaN
#
#            model  n_cylinders  odometer  price  \
# 0            J11            4     43459   9990
# 1      Wall X200            4     46651  10990
# ...

# %%
data.iloc[3].url
# Out:
# 'carsales.com.au/private/details/Holden-Trax-2014/SSE-AD-5530653/?Cr=3'

# %%
# find average price per make/model
# group by?
data.groupby(['make', 'model']).mean()
# Out:
#                                         engine_capacity  \
# make       model
# Chery      J11                                      1.6
# Ford       Kuga Ambiente TF                         1.6
#            Kuga Trend TF                            1.6
# Great      Wall X200                                2.0
# Holden     Trax Active TJ                           1.8
#            Trax Black TJ                            1.8
#            Trax LS TJ                               1.8
#            Trax LTZ TJ                              1.8
# Hyundai    ix35 SE                                  2.0
#            ix35 Trophy                              2.0
# Jeep       Compass Blackhawk                        2.0
#            Compass North                            2.0
#            Compass Sport                            2.0
#            Patriot Sport                            2.0
#            Renegade Sport                           1.6
# ...
